# %% [markdown]
# # QUBO Playground
#
# Experiment with QUBO formulations using synthetic and real plant anomaly data.
#
# ## Objectives
# - Visualize energy landscapes for small problem instances
# - Verify optimal solutions through brute-force enumeration
# - Develop intuition for how hyperparameter choices affect solution characteristics
# - Test edge cases: single-sensor anomalies, multiple simultaneous patterns, topology constraint violations

# %%
# TODO: Implement QUBO exploration notebook
import numpy as np
from psq.qubo.model import build_root_cause_qubo
from psq.data.schemas import SensorAbnormal, RootCausePattern
